# %% [markdown]
# # Update circuits
#
# This script searches for new circuits from the 'circuits.csv' file in the Minio object store. It compares them against circuits already listed in the database and inserts any new ones.
#
# #### ToDo:
# - Improve the matching logic, it is susceptible to false positives.
# - Quarantine records that may be incorrect.
# - Add a results reporting function.
# - Add additional metadata.
# - Make logic performance improvements.

# %%
import pandas as pd
import numpy as np
from io import BytesIO
from minio import Minio
from sqlalchemy import create_engine, text
from fuzzywuzzy import fuzz
from datetime import datetime
import re
import logging
import psycopg2
# from psycopg2.extras import execute_batch

# %%
# logging.basicConfig(format='%(asctime)s %(levelname)s - %(message)s', level=logging.INFO)
logger =logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s.%(msecs)03d %(levelname)s %(module)s - %(funcName)s: %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
)
logger = logging.getLogger(__name__)
# logger=logging.basicConfig(level=logging.INFO, format='%(asctime)s %(levelname)s:%(message)s')
# logger = logging.getLogger()

# %%
try:
    logger.info("Trying MinIO Initilization.")
    # Initialize Minio client
    minio_client = Minio(
        "minio:9000",
        access_key="minioadmin",
        secret_key="minioadmin",
        secure=False
    )
    logger.info("MinIO Initialized .")
except Exception as e:
    logger.error("MinIO client initialisation error: %s", e)

try:
    # Download the CSV file from the Minio bucket into a pandas DataFrame
    data = minio_client.get_object("track.data-raw", "circuits.csv")
    data = BytesIO(data.read())
    df_csv = pd.read_csv(data)
    logger.info("Circuits file with %s records downloaded and read into DataFrame 'df_csv'", len(df_csv))
except Exception as e:
    logger.error("Circuits file download/read error: %s", e)
pd.set_option('display.max_rows', None)
# Out:
# 2023-10-02 08:00:42.434 INFO 1018797224 - <module>: Trying MinIO Initilization.
# 2023-10-02 08:00:42.439 INFO 1018797224 - <module>: MinIO Initialized .
# 2023-10-02 08:00:42.504 INFO 1018797224 - <module>: Circuits file with 77 records downloaded and read into DataFrame 'df_csv'

# %%
df_csv.sort_values(by=['location','circuitRef', 'name'])
# Out:
#     circuitId      circuitRef                                   name  \
# 23         24      yas_marina                     Yas Marina Circuit
# 28         29        adelaide                Adelaide Street Circuit
# 75         78          losail           Losail International Circuit
# 46         47      anderstorp                   Scandinavian Raceway
# 68         69        americas                Circuit of the Americas
# 71         73            baku                      Baku City Circuit
# 48         49        montjuic                               Montjuïc
# 66         67       pedralbes                   Circuit de Pedralbes
# 60         61            avus                                   AVUS
# 65         66      bremgarten                     Circuit Bremgarten
# 49         50        nivelles                       Nivelles-Baulers
# 10         11     hungaroring                            Hungaroring
# 24         25          galvez          Autódromo Juan y Oscar Gálvez
# 42         43      long_beach                             Long Beach
# 59         60       riverside        Riverside International Raceway
# 63         64        ain-diab                               Ain Diab
# 30         31       donington                         Donington Park
# 50         51         charade                        Charade Circuit
# 41         42          dallas                              Fair Park
# 36         37         detroit                 Detroit Street Circuit
# 40         41           dijon                          Dijon-Prenois
# 55         56          george                  Prince George Circuit
# 26         27         estoril                   Autódromo do Estoril
# 62         63         sebring          Sebring International Raceway
# 39         40          zolder                                 Zolder
# 9          10  hockenheimring                         Hockenheimring
# 20         21           imola          Autodromo Enzo e Dino Ferrari
# 18         19    indianapolis            Indianapolis Motor Speedway
# 4           5        istanbul                          Istanbul Park
# 74         77          jeddah                Jeddah Corniche Circuit
# 25         26           jerez                      Circuito de Jerez
# 37         38    brands_hatch                           Brands Hatch
# 1           2          sepang           Sepang International Circuit
# 22         80           vegas         Las Vegas Strip Street Circuit
# 33         34          ricard                    Circuit Paul Ricard
# 53         54          lemans                                Le Mans
# 61         62        monsanto                  Monsanto Park Circuit
# 57         58         aintree                                Aintree
# 44         45          jarama                                 Jarama
# 7           8     magny_cours          Circuit de Nevers Magny-Cours
# 14         15      marina_bay              Marina Bay Street Circuit
# 0           1     albert_park         Albert Park Grand Prix Circuit
# 31         32       rodriguez           Autódromo Hermanos Rodríguez
# 76         79           miami          Miami International Autodrome
# 29         30         kyalami                                Kyalami
# 5           6          monaco                      Circuit de Monaco
# 3           4       catalunya         Circuit de Barcelona-Catalunya
# 6           7      villeneuve              Circuit Gilles Villeneuve
# 13         14           monza           Autodromo Nazionale di Monza
# 73         76         mugello   Autodromo Internazionale del Mugello
# 43         44       las_vegas               Las Vegas Street Circuit
# 45         46    watkins_glen                           Watkins Glen
# 19         20     nurburgring                            Nürburgring
# 27         28         okayama          Okayama International Circuit
# 47         48         mosport          Mosport International Raceway
# 58         59        boavista                   Circuito da Boavista
# 15         16            fuji                          Fuji Speedway
# 64         65         pescara                        Pescara Circuit
# 32         33         phoenix                 Phoenix street circuit
# 72         75        portimao     Autódromo Internacional do Algarve
# 51         52       tremblant                 Circuit Mont-Tremblant
# 54         55           reims                            Reims-Gueux
# 35         36     jacarepagua  Autódromo Internacional Nelson Piquet
# 52         53         essarts                      Rouen-Les-Essarts
# 2           3         bahrain          Bahrain International Circuit
# 16         17        shanghai         Shanghai International Circuit
# 8           9     silverstone                    Silverstone Circuit
# 70         71           sochi                         Sochi Autodrom
# 12         13             spa           Circuit de Spa-Francorchamps
# 69         70   red_bull_ring                          Red Bull Ring
# 56         57         zeltweg                                Zeltweg
# 21         22          suzuka                         Suzuka Circuit
# 17         18      interlagos             Autódromo José Carlos Pace
# 67         68           buddh            Buddh International Circuit
# 11         12        valencia                Valencia Street Circuit
# 34         35         yeongam           Korean International Circuit
# 38         39       zandvoort                 Circuit Park Zandvoort
#
#                  location        country       lat         lng   alt  \
# 23              Abu Dhabi            UAE  24.46720   54.603100     3
# 28               Adelaide      Australia -34.92720  138.617000    58
# 75              Al Daayen          Qatar  25.49000   51.454200    \N
# 46             Anderstorp         Sweden  57.26530   13.604200   153
# 68                 Austin            USA  30.13280  -97.641100   161
# 71                   Baku     Azerbaijan  40.37250   49.853300    -7
# 48              Barcelona          Spain  41.36640    2.151670    79
# 66              Barcelona          Spain  41.39030    2.116670    85
# 60                 Berlin        Germany  52.48060   13.251400    53
# 65                   Bern    Switzerland  46.95890    7.401940   551
# 49               Brussels        Belgium  50.62110    4.326940   139
# 10               Budapest        Hungary  47.57890   19.248600   264
# 24           Buenos Aires      Argentina -34.69430  -58.459300     8
# 42             California            USA  33.76510 -118.189000    12
# 59             California            USA  33.93700 -117.273000   470
# 63             Casablanca        Morocco  33.57860   -7.687500    19
# 30       Castle Donington             UK  52.83060   -1.375280    88
# 50       Clermont-Ferrand         France  45.74720    3.038890   790
# 41                 Dallas            USA  32.77740  -96.758700   139
# 36                Detroit            USA  42.32980  -83.040100   177
# 40                  Dijon         France  47.36250    4.899130   484
# 55  Eastern Cape Province   South Africa -33.04860   27.873600    15
# 26                Estoril       Portugal  38.75060   -9.394170   130
# 62                Florida            USA  27.45470  -81.348300    18
# 39         Heusden-Zolder        Belgium  50.98940    5.256940    36
# 9              Hockenheim        Germany  49.32780    8.565830   103
# 20                  Imola          Italy  44.34390   11.716700    37
# 18           Indianapolis            USA  39.79500  -86.234700   223
# 4                Istanbul         Turkey  40.95170   29.405000   130
# 74                 Jeddah   Saudi Arabia  21.63190   39.104400    15
# 25   Jerez de la Frontera          Spain  36.70830   -6.034170    37
# 37                   Kent             UK  51.35690    0.263056   145
# 1            Kuala Lumpur       Malaysia   2.76083  101.738000    18
# 22              Las Vegas  United States  36.11470 -115.173000    \N
# 33           Le Castellet         France  43.25060    5.791670   432
# 53                Le Mans         France  47.95000    0.224231    67
# 61                 Lisbon       Portugal  38.71970   -9.203060   158
# 57              Liverpool             UK  53.47690   -2.940560    20
# 44                 Madrid          Spain  40.61710   -3.585580   609
# 7             Magny Cours         France  46.86420    3.163610   228
# 14             Marina Bay      Singapore   1.29140  103.864000    18
# 0               Melbourne      Australia -37.84970  144.968000    10
# 31            Mexico City         Mexico  19.40420  -99.090700  2227
# 76                  Miami            USA  25.95810  -80.238900    \N
# 29                Midrand   South Africa -25.98940   28.076700  1460
# 5             Monte-Carlo         Monaco  43.73470    7.420560     7
# 3                Montmeló          Spain  41.57000    2.261110   109
# 6                Montreal         Canada  45.50000  -73.522800    13
# 13                  Monza          Italy  45.61560    9.281110   162
# 73                Mugello          Italy  43.99750   11.371900   255
# 43                 Nevada            USA  36.11620 -115.174000   639
# 45         New York State            USA  42.33690  -76.927200   485
# 19                Nürburg        Germany  50.33560    6.947500   578
# 27                Okayama          Japan  34.91500  134.221000   266
# 47                Ontario         Canada  44.04810  -78.675600   332
# 58                 Oporto       Portugal  41.17050   -8.673250    28
# 15                  Oyama          Japan  35.37170  138.927000   583
# 64                Pescara          Italy  42.47500   14.150800   129
# 32                Phoenix            USA  33.44790 -112.075000   345
# 72               Portimão       Portugal  37.22700   -8.626700   108
# 51                 Quebec         Canada  46.18770  -74.609900   214
# 54                  Reims         France  49.25420    3.930830    88
# 35         Rio de Janeiro         Brazil -22.97560  -43.395000  1126
# 52                  Rouen         France  49.33060    1.004580    81
# 2                  Sakhir        Bahrain  26.03250   50.510600     7
# 16               Shanghai          China  31.33890  121.220000     5
# 8             Silverstone             UK  52.07860   -1.016940   153
# 70                  Sochi         Russia  43.40570   39.957800     2
# 12                    Spa        Belgium  50.43720    5.971390   401
# 69              Spielberg        Austria  47.21970   14.764700   678
# 56                 Styria        Austria  47.20390   14.747800   676
# 21                 Suzuka          Japan  34.84310  136.541000    45
# 17              São Paulo         Brazil -23.70360  -46.699700   785
# 67          Uttar Pradesh          India  28.34870   77.533100   194
# 11               Valencia          Spain  39.45890   -0.331667     4
# 34         Yeongam County          Korea  34.73330  126.417000     0
# 38              Zandvoort    Netherlands  52.38880    4.540920     6
#
#                                                   url
# 23    http://en.wikipedia.org/wiki/Yas_Marina_Circuit
# 28  http://en.wikipedia.org/wiki/Adelaide_Street_C...
# 75  http://en.wikipedia.org/wiki/Losail_Internatio...
# 46  http://en.wikipedia.org/wiki/Scandinavian_Raceway
# 68  http://en.wikipedia.org/wiki/Circuit_of_the_Am...
# 71     http://en.wikipedia.org/wiki/Baku_City_Circuit
# 48  http://en.wikipedia.org/wiki/Montju%C3%AFc_cir...
# 66     http://en.wikipedia.org/wiki/Pedralbes_Circuit
# 60                  http://en.wikipedia.org/wiki/AVUS
# 65    http://en.wikipedia.org/wiki/Circuit_Bremgarten
# 49      http://en.wikipedia.org/wiki/Nivelles-Baulers
# 10           http://en.wikipedia.org/wiki/Hungaroring
# 24  http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Os...
# 42  http://en.wikipedia.org/wiki/Long_Beach,_Calif...
# 59  http://en.wikipedia.org/wiki/Riverside_Interna...
# 63      http://en.wikipedia.org/wiki/Ain-Diab_Circuit
# 30        http://en.wikipedia.org/wiki/Donington_Park
# 50       http://en.wikipedia.org/wiki/Charade_Circuit
# 41             http://en.wikipedia.org/wiki/Fair_Park
# 36  http://en.wikipedia.org/wiki/Detroit_street_ci...
# 40         http://en.wikipedia.org/wiki/Dijon-Prenois
# 55  http://en.wikipedia.org/wiki/Prince_George_Cir...
# 26  http://en.wikipedia.org/wiki/Aut%C3%B3dromo_do...
# 62       http://en.wikipedia.org/wiki/Sebring_Raceway
# 39                http://en.wikipedia.org/wiki/Zolder
# 9         http://en.wikipedia.org/wiki/Hockenheimring
# 20  http://en.wikipedia.org/wiki/Autodromo_Enzo_e_...
# 18  http://en.wikipedia.org/wiki/Indianapolis_Moto...
# 4          http://en.wikipedia.org/wiki/Istanbul_Park
# 74  http://en.wikipedia.org/wiki/Jeddah_Street_Cir...
# 25  http://en.wikipedia.org/wiki/Circuito_Permanen...
# 37          http://en.wikipedia.org/wiki/Brands_Hatch
# 1   http://en.wikipedia.org/wiki/Sepang_Internatio...
# 22  https://en.wikipedia.org/wiki/Las_Vegas_Grand_...
# 33   http://en.wikipedia.org/wiki/Paul_Ricard_Circuit
# 53  http://en.wikipedia.org/wiki/Circuit_de_la_Sar...
# 61  http://en.wikipedia.org/wiki/Monsanto_Park_Cir...
# 57  http://en.wikipedia.org/wiki/Aintree_Motor_Rac...
# 44  http://en.wikipedia.org/wiki/Circuito_Permanen...
# 7   http://en.wikipedia.org/wiki/Circuit_de_Nevers...
# 14  http://en.wikipedia.org/wiki/Marina_Bay_Street...
# 0   http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 31  http://en.wikipedia.org/wiki/Aut%C3%B3dromo_He...
# 76  http://en.wikipedia.org/wiki/Miami_Internation...
# 29               http://en.wikipedia.org/wiki/Kyalami
# 5      http://en.wikipedia.org/wiki/Circuit_de_Monaco
# 3   http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 6   http://en.wikipedia.org/wiki/Circuit_Gilles_Vi...
# 13  http://en.wikipedia.org/wiki/Autodromo_Naziona...
# 73       http://en.wikipedia.org/wiki/Mugello_Circuit
# 43  http://en.wikipedia.org/wiki/Las_Vegas_Street_...
# 45  http://en.wikipedia.org/wiki/Watkins_Glen_Inte...
# 19      http://en.wikipedia.org/wiki/N%C3%BCrburgring
# 27            http://en.wikipedia.org/wiki/TI_Circuit
# 47               http://en.wikipedia.org/wiki/Mosport
# 58  http://en.wikipedia.org/wiki/Circuito_da_Boavista
# 15         http://en.wikipedia.org/wiki/Fuji_Speedway
# 64       http://en.wikipedia.org/wiki/Pescara_Circuit
# 32  http://en.wikipedia.org/wiki/Phoenix_street_ci...
# 72  http://en.wikipedia.org/wiki/Algarve_Internati...
# 51  http://en.wikipedia.org/wiki/Circuit_Mont-Trem...
# 54           http://en.wikipedia.org/wiki/Reims-Gueux
# 35  http://en.wikipedia.org/wiki/Aut%C3%B3dromo_In...
# 52     http://en.wikipedia.org/wiki/Rouen-Les-Essarts
# 2   http://en.wikipedia.org/wiki/Bahrain_Internati...
# 16  http://en.wikipedia.org/wiki/Shanghai_Internat...
# 8    http://en.wikipedia.org/wiki/Silverstone_Circuit
# 70        http://en.wikipedia.org/wiki/Sochi_Autodrom
# 12  http://en.wikipedia.org/wiki/Circuit_de_Spa-Fr...
# 69         http://en.wikipedia.org/wiki/Red_Bull_Ring
# 56      http://en.wikipedia.org/wiki/Zeltweg_Airfield
# 21        http://en.wikipedia.org/wiki/Suzuka_Circuit
# 17  http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Jo...
# 67  http://en.wikipedia.org/wiki/Buddh_Internation...
# 11  http://en.wikipedia.org/wiki/Valencia_Street_C...
# 34  http://en.wikipedia.org/wiki/Korean_Internatio...
# 38     http://en.wikipedia.org/wiki/Circuit_Zandvoort

# %%
# Initialize connection to the PostgreSQL database using SQLAlchemy
try:
    logger.info("Trying database connection.")
    engine = create_engine('postgresql://admin:admin@pgdb/postgres')
    logger.info("Database connection successful.")
except Exception as e:
    logger.error("Error during database connection: %s", e)
# Out:
# 2023-10-02 08:00:42.549 INFO 1615689807 - <module>: Trying database connection.
# 2023-10-02 08:00:42.608 INFO 1615689807 - <module>: Database connection successful.

# %%
# Query the database to get the current circuits
df_db = pd.read_sql("SELECT * FROM race_data.circuits", engine)

# %%
df_db.sort_values(by=['location','circuit_reference', 'name'])
# Out:
#     circuit_id circuit_reference  \
# 22          23         Abu Dhabi
# 19          20            Austin
# 14          15              Baku
# 18          19             Hanoi
# 12          13             Imola
# 21          22            Jeddah
# 23          24         Las Vegas
# 15          16       Paul Ricard
# 1            2         Melbourne
# 20          21            Mexico
# 24          25             Miami
# 16          17       Hungaroring
# 13          14            Monaco
# 4            5         Barcelona
# 0            1          Montreal
# 6            7             Monza
# 8            9       Nurburgring
# 9           10          Portimao
# 11          12            Sakhir
# 10          11           Mugello
# 3            4       Silverstone
# 7            8             Sochi
# 5            6               Spa
# 2            3         Spielberg
# 17          18         Zandvoort
#
#                                             name               location  \
# 22                            Yas Marina Circuit              Abu Dhabi
# 19                       Circuit of The Americas                 Austin
# 14                             Baku City Circuit                   Baku
# 18                          Hanoi Street Circuit                  Hanoi
# 12  Autodromo Internazionale Enzo e Dino Ferrari                  Imola
# 21                         Jeddah Street Circuit                 Jeddah
# 23                      Las Vegas Street Circuit              Las Vegas
# 15                           Circuit Paul Ricard           Le Castellet
# 1                   Melbourne Grand Prix Circuit              Melbourne
# 20                  Autódromo Hermanos Rodríguez            Mexico City
# 24                 Miami International Autodrome                  Miami
# 16                                   Hungaroring               Mogyorod
# 13                             Circuit de Monaco            Monte Carlo
# 4                 Circuit de Barcelona-Catalunya               Montmelo
# 0                      Circuit Gilles-Villeneuve               Montreal
# 6                      Autodromo Nazionale Monza                  Monza
# 8                                    Nürburgring                Nürburg
# 9             Autódromo Internacional do Algarve               Portimão
# 11                 Bahrain International Circuit                 Sakhir
# 10          Autodromo Internazionale del Mugello  Scarperia e San Piero
# 3                            Silverstone Circuit            Silverstone
# 7                                 Sochi Autodrom                  Sochi
# 5                   Circuit de Spa-Francorchamps      Spa Francorchamps
# 2                                  Red Bull Ring              Spielberg
# 17                             Circuit Zandvoort              Zandvoort
#
#         lat      lng
# 22  24.4700   54.603
# 19  30.1330  -97.641
# 14  40.3720   49.853
# 18  21.0210  105.843
# 12  44.3430   11.716
# 21  21.5270   39.187
# 23  36.1690 -115.136
# 15  43.2510    5.793
# 1  -37.8497  144.968
# 20  19.4060  -99.090
# 24  25.7780  -80.202
# 16  47.5810   19.250
# 13  43.7350    7.421
# 4   41.5690    2.261
# 0   45.5060  -73.525
# 6   45.6210    9.290
# 8   50.3340    6.943
# 9   37.2320   -8.628
# 11  26.0310   50.512
# 10  43.9980   11.372
# 3   52.0720   -1.017
# 7   43.4070   39.960
# 5   50.4360    5.971
# 2   47.2230   14.761
# 17  52.3890    4.541

# %%
# Define a threshold for the fuzz.ratio. This depends on how strict you want your matching to be.
threshold = 80

# %% [markdown]
# # Logics
#
# ## Lookup Logic:
# - Clean and normalise the data. Standardise all the non-englisht characters into english, replace special characters from data with a blank space, strip the data set.
# - alter the table and add a new column to it to add created_date metadata information
# - Keeping df_csf as left and df_db as right, perform a left join on location.
#
# #### If records only in db_csv(left df):
# - Initialise a blank df named 'df_insert' having the schema same as that of target table
# - Initialise a blank df named 'df_quarantine' having the schema same as that of target table
# - Perform a check to find potentially incorrect records and quarantine them
# - Add all the non Quarantined records to 'df_quarantine'
# - Insert rest of the records in 'df_insert'
#
# #### If records in both the df:
# - Since one location can have more than one circuits, find fuzzy match on name, circuit_ref and cordinates, if match not found, append the records to 'df_insert'.
# - If match not found, do not load the records.

# %%
try:
    logger.info("Cleansing and normalisation initiated.")
    # remove special characters and non-alphanumeric characters
    remove_special_chars = lambda text: re.sub(r'[^a-zA-Z0-9\s]', '', text)
    
    # data cleansing and normalization for accent characters
    
    clean_normalize = lambda s: re.sub(r'[àáâãäå]', 'a', re.sub(r'[éèêë]', 'e', re.sub(r'[íìîïí]', 'i', re.sub(r'[òóôõö]', 'o', re.sub(r'[úùûü]', 'u', re.sub(r'[ýÿ]', 'y',s)))))) \
                                     .replace('-', ' ') \
                                    .replace('_', ' ') \
                                     .strip()
    
    # Creating list of columns to clean
    columns_to_clean_db = ['circuit_reference', 'name', 'location']
    columns_to_clean_csv = ['circuitRef', 'name', 'location']
    
    # Apply the lambda functions to the specified columns in both DataFrames
    for column in columns_to_clean_db:
        # fill na values with bulls before cleaning
        df_db[column] = df_db[column].fillna('').apply(str)
        #normalise and cleanse
        df_db[column] = df_db[column].apply(clean_normalize).apply(remove_special_chars)
    for column in columns_to_clean_csv:
        # fill na values with bulls before cleaning
        df_csv[column] = df_csv[column].fillna('').apply(str)
        #normalise and cleanse
        df_csv[column] = df_csv[column].apply(clean_normalize).apply(remove_special_chars)
    logger.info("Cleansing and normalisation completed.")
except Exception as e:
    logger.error("Error %s occured during cleansing and standardisation", e)
# Out:
# 2023-10-02 08:00:42.718 INFO 2151163984 - <module>: Cleansing and normalisation initiated.
# 2023-10-02 08:00:42.731 INFO 2151163984 - <module>: Cleansing and normalisation completed.

# %%
df_csv.drop(['alt', 'url'], axis=1,inplace=True)
df_csv.sort_values(by=['location','circuitRef', 'name'])
# Out:
#     circuitId      circuitRef                                   name  \
# 23         24      yas marina                     Yas Marina Circuit
# 28         29        adelaide                Adelaide Street Circuit
# 75         78          losail           Losail International Circuit
# 46         47      anderstorp                   Scandinavian Raceway
# 68         69        americas                Circuit of the Americas
# 71         73            baku                      Baku City Circuit
# 48         49        montjuic                               Montjuic
# 66         67       pedralbes                   Circuit de Pedralbes
# 60         61            avus                                   AVUS
# 65         66      bremgarten                     Circuit Bremgarten
# 49         50        nivelles                       Nivelles Baulers
# 10         11     hungaroring                            Hungaroring
# 24         25          galvez          Autodromo Juan y Oscar Galvez
# 42         43      long beach                             Long Beach
# 59         60       riverside        Riverside International Raceway
# 63         64        ain diab                               Ain Diab
# 30         31       donington                         Donington Park
# 50         51         charade                        Charade Circuit
# 41         42          dallas                              Fair Park
# 36         37         detroit                 Detroit Street Circuit
# 40         41           dijon                          Dijon Prenois
# 55         56          george                  Prince George Circuit
# 26         27         estoril                   Autodromo do Estoril
# 62         63         sebring          Sebring International Raceway
# 39         40          zolder                                 Zolder
# 9          10  hockenheimring                         Hockenheimring
# 20         21           imola          Autodromo Enzo e Dino Ferrari
# 18         19    indianapolis            Indianapolis Motor Speedway
# 4           5        istanbul                          Istanbul Park
# 74         77          jeddah                Jeddah Corniche Circuit
# 25         26           jerez                      Circuito de Jerez
# 37         38    brands hatch                           Brands Hatch
# 1           2          sepang           Sepang International Circuit
# 22         80           vegas         Las Vegas Strip Street Circuit
# 33         34          ricard                    Circuit Paul Ricard
# 53         54          lemans                                Le Mans
# 61         62        monsanto                  Monsanto Park Circuit
# 57         58         aintree                                Aintree
# 44         45          jarama                                 Jarama
# 7           8     magny cours          Circuit de Nevers Magny Cours
# 14         15      marina bay              Marina Bay Street Circuit
# 0           1     albert park         Albert Park Grand Prix Circuit
# 31         32       rodriguez           Autodromo Hermanos Rodriguez
# 76         79           miami          Miami International Autodrome
# 29         30         kyalami                                Kyalami
# 5           6          monaco                      Circuit de Monaco
# 3           4       catalunya         Circuit de Barcelona Catalunya
# 6           7      villeneuve              Circuit Gilles Villeneuve
# 13         14           monza           Autodromo Nazionale di Monza
# 73         76         mugello   Autodromo Internazionale del Mugello
# 43         44       las vegas               Las Vegas Street Circuit
# 45         46    watkins glen                           Watkins Glen
# 19         20     nurburgring                            Nurburgring
# 27         28         okayama          Okayama International Circuit
# 47         48         mosport          Mosport International Raceway
# 58         59        boavista                   Circuito da Boavista
# 15         16            fuji                          Fuji Speedway
# 64         65         pescara                        Pescara Circuit
# 32         33         phoenix                 Phoenix street circuit
# 72         75        portimao     Autodromo Internacional do Algarve
# 51         52       tremblant                 Circuit Mont Tremblant
# 54         55           reims                            Reims Gueux
# 35         36     jacarepagua  Autodromo Internacional Nelson Piquet
# 52         53         essarts                      Rouen Les Essarts
# 2           3         bahrain          Bahrain International Circuit
# 17         18      interlagos             Autodromo Jose Carlos Pace
# 16         17        shanghai         Shanghai International Circuit
# 8           9     silverstone                    Silverstone Circuit
# 70         71           sochi                         Sochi Autodrom
# 12         13             spa           Circuit de Spa Francorchamps
# 69         70   red bull ring                          Red Bull Ring
# 56         57         zeltweg                                Zeltweg
# 21         22          suzuka                         Suzuka Circuit
# 67         68           buddh            Buddh International Circuit
# 11         12        valencia                Valencia Street Circuit
# 34         35         yeongam           Korean International Circuit
# 38         39       zandvoort                 Circuit Park Zandvoort
#
#                  location        country       lat         lng
# 23              Abu Dhabi            UAE  24.46720   54.603100
# 28               Adelaide      Australia -34.92720  138.617000
# 75              Al Daayen          Qatar  25.49000   51.454200
# 46             Anderstorp         Sweden  57.26530   13.604200
# 68                 Austin            USA  30.13280  -97.641100
# 71                   Baku     Azerbaijan  40.37250   49.853300
# 48              Barcelona          Spain  41.36640    2.151670
# 66              Barcelona          Spain  41.39030    2.116670
# 60                 Berlin        Germany  52.48060   13.251400
# 65                   Bern    Switzerland  46.95890    7.401940
# 49               Brussels        Belgium  50.62110    4.326940
# 10               Budapest        Hungary  47.57890   19.248600
# 24           Buenos Aires      Argentina -34.69430  -58.459300
# 42             California            USA  33.76510 -118.189000
# 59             California            USA  33.93700 -117.273000
# 63             Casablanca        Morocco  33.57860   -7.687500
# 30       Castle Donington             UK  52.83060   -1.375280
# 50       Clermont Ferrand         France  45.74720    3.038890
# 41                 Dallas            USA  32.77740  -96.758700
# 36                Detroit            USA  42.32980  -83.040100
# 40                  Dijon         France  47.36250    4.899130
# 55  Eastern Cape Province   South Africa -33.04860   27.873600
# 26                Estoril       Portugal  38.75060   -9.394170
# 62                Florida            USA  27.45470  -81.348300
# 39         Heusden Zolder        Belgium  50.98940    5.256940
# 9              Hockenheim        Germany  49.32780    8.565830
# 20                  Imola          Italy  44.34390   11.716700
# 18           Indianapolis            USA  39.79500  -86.234700
# 4                Istanbul         Turkey  40.95170   29.405000
# 74                 Jeddah   Saudi Arabia  21.63190   39.104400
# 25   Jerez de la Frontera          Spain  36.70830   -6.034170
# 37                   Kent             UK  51.35690    0.263056
# 1            Kuala Lumpur       Malaysia   2.76083  101.738000
# 22              Las Vegas  United States  36.11470 -115.173000
# 33           Le Castellet         France  43.25060    5.791670
# 53                Le Mans         France  47.95000    0.224231
# 61                 Lisbon       Portugal  38.71970   -9.203060
# 57              Liverpool             UK  53.47690   -2.940560
# 44                 Madrid          Spain  40.61710   -3.585580
# 7             Magny Cours         France  46.86420    3.163610
# 14             Marina Bay      Singapore   1.29140  103.864000
# 0               Melbourne      Australia -37.84970  144.968000
# 31            Mexico City         Mexico  19.40420  -99.090700
# 76                  Miami            USA  25.95810  -80.238900
# 29                Midrand   South Africa -25.98940   28.076700
# 5             Monte Carlo         Monaco  43.73470    7.420560
# 3                Montmelo          Spain  41.57000    2.261110
# 6                Montreal         Canada  45.50000  -73.522800
# 13                  Monza          Italy  45.61560    9.281110
# 73                Mugello          Italy  43.99750   11.371900
# 43                 Nevada            USA  36.11620 -115.174000
# 45         New York State            USA  42.33690  -76.927200
# 19                Nurburg        Germany  50.33560    6.947500
# 27                Okayama          Japan  34.91500  134.221000
# 47                Ontario         Canada  44.04810  -78.675600
# 58                 Oporto       Portugal  41.17050   -8.673250
# 15                  Oyama          Japan  35.37170  138.927000
# 64                Pescara          Italy  42.47500   14.150800
# 32                Phoenix            USA  33.44790 -112.075000
# 72               Portimao       Portugal  37.22700   -8.626700
# 51                 Quebec         Canada  46.18770  -74.609900
# 54                  Reims         France  49.25420    3.930830
# 35         Rio de Janeiro         Brazil -22.97560  -43.395000
# 52                  Rouen         France  49.33060    1.004580
# 2                  Sakhir        Bahrain  26.03250   50.510600
# 17              Sao Paulo         Brazil -23.70360  -46.699700
# 16               Shanghai          China  31.33890  121.220000
# 8             Silverstone             UK  52.07860   -1.016940
# 70                  Sochi         Russia  43.40570   39.957800
# 12                    Spa        Belgium  50.43720    5.971390
# 69              Spielberg        Austria  47.21970   14.764700
# 56                 Styria        Austria  47.20390   14.747800
# 21                 Suzuka          Japan  34.84310  136.541000
# 67          Uttar Pradesh          India  28.34870   77.533100
# 11               Valencia          Spain  39.45890   -0.331667
# 34         Yeongam County          Korea  34.73330  126.417000
# 38              Zandvoort    Netherlands  52.38880    4.540920

# %%
df_db.sort_values(by=['location','circuit_reference', 'name'])
# Out:
#     circuit_id circuit_reference  \
# 22          23         Abu Dhabi
# 19          20            Austin
# 14          15              Baku
# 18          19             Hanoi
# 12          13             Imola
# 21          22            Jeddah
# 23          24         Las Vegas
# 15          16       Paul Ricard
# 1            2         Melbourne
# 20          21            Mexico
# 24          25             Miami
# 16          17       Hungaroring
# 13          14            Monaco
# 4            5         Barcelona
# 0            1          Montreal
# 6            7             Monza
# 8            9       Nurburgring
# 9           10          Portimao
# 11          12            Sakhir
# 10          11           Mugello
# 3            4       Silverstone
# 7            8             Sochi
# 5            6               Spa
# 2            3         Spielberg
# 17          18         Zandvoort
#
#                                             name               location  \
# 22                            Yas Marina Circuit              Abu Dhabi
# 19                       Circuit of The Americas                 Austin
# 14                             Baku City Circuit                   Baku
# 18                          Hanoi Street Circuit                  Hanoi
# 12  Autodromo Internazionale Enzo e Dino Ferrari                  Imola
# 21                         Jeddah Street Circuit                 Jeddah
# 23                      Las Vegas Street Circuit              Las Vegas
# 15                           Circuit Paul Ricard           Le Castellet
# 1                   Melbourne Grand Prix Circuit              Melbourne
# 20                  Autodromo Hermanos Rodriguez            Mexico City
# 24                 Miami International Autodrome                  Miami
# 16                                   Hungaroring               Mogyorod
# 13                             Circuit de Monaco            Monte Carlo
# 4                 Circuit de Barcelona Catalunya               Montmelo
# 0                      Circuit Gilles Villeneuve               Montreal
# 6                      Autodromo Nazionale Monza                  Monza
# 8                                    Nurburgring                Nurburg
# 9             Autodromo Internacional do Algarve               Portimao
# 11                 Bahrain International Circuit                 Sakhir
# 10          Autodromo Internazionale del Mugello  Scarperia e San Piero
# 3                            Silverstone Circuit            Silverstone
# 7                                 Sochi Autodrom                  Sochi
# 5                   Circuit de Spa Francorchamps      Spa Francorchamps
# 2                                  Red Bull Ring              Spielberg
# 17                             Circuit Zandvoort              Zandvoort
#
#         lat      lng
# 22  24.4700   54.603
# 19  30.1330  -97.641
# 14  40.3720   49.853
# 18  21.0210  105.843
# 12  44.3430   11.716
# 21  21.5270   39.187
# 23  36.1690 -115.136
# 15  43.2510    5.793
# 1  -37.8497  144.968
# 20  19.4060  -99.090
# 24  25.7780  -80.202
# 16  47.5810   19.250
# 13  43.7350    7.421
# 4   41.5690    2.261
# 0   45.5060  -73.525
# 6   45.6210    9.290
# 8   50.3340    6.943
# 9   37.2320   -8.628
# 11  26.0310   50.512
# 10  43.9980   11.372
# 3   52.0720   -1.017
# 7   43.4070   39.960
# 5   50.4360    5.971
# 2   47.2230   14.761
# 17  52.3890    4.541

# %% [markdown]
# Performing a left join on Location between the two data frames
#
# - Here we will use location column to merge the dataframes

# %%
merged_df_csv=df_csv.merge(df_db, on='location', how='left', indicator=True)[['circuitId','circuitRef','name_x','location','country','lat_x','lng_x','_merge']].sort_values(by=['location'])

# To get better performance, we can also set the index of both dtaframes as location and Later we will reset the index

# %%
merged_df_csv.dtypes
# Out:
# circuitId        int64
# circuitRef      object
# name_x          object
# location        object
# country         object
# lat_x          float64
# lng_x          float64
# _merge        category
# dtype: object

# %% [markdown]
# #### Old data loader
#
# Improvements made:
# - Removed itterrows as it is very inefficient
# - Iterating over numpy array instead, hightly effecient
# - Using data based on the merge perfomed earlier to filter data and improve performance
# - Added logic to identify and quarantine potentially error records
# - Removee the logic that was inserting each row at a time. New logic creates a dataframe of all the records to be inserted and then inserts the whole dataframe all at once to the table. Inserting each row everytime in each iteration is a very costly logic.

# %%
def result_report(insert_list: list , quarantine_lst: list):
    try:
        logger.info("Report - Total # of new circuits inserted is: %d, Total # of circuits quarantined for analysis is: %d", len(insert_list), len(quarantine_lst))
    except Exception as e:
        logger.error("Error in report_results function: %s", e)

# %%
try:
    logger.info("Analysing and filtering datasets")
    quarantine_lst=[]
    insert_list=[]
    for row_csv in merged_df_csv.to_numpy():
        csv_circuit_ref = row_csv[1]
        csv_circuit_name = row_csv[2]
        csv_circuit_lat = round(row_csv[5],2)
        csv_circuit_lng = round(row_csv[6],2)
        
        match_found = False
        
        for row_db in df_db.to_numpy():
            db_circuit_ref = row_db[1]
            db_circuit_name = row_db[2]
            db_circuit_lat = round(row_db[4],2)
            db_circuit_lng = round(row_db[5],2)
    
            circuit_ref_score=fuzz.ratio(csv_circuit_ref.lower(), db_circuit_ref.lower())
            name_score=fuzz.ratio(csv_circuit_name.lower(), db_circuit_name.lower())
            lat_score=fuzz.ratio(str(csv_circuit_lat).lower(), str(db_circuit_lat).lower())
            lng_score=fuzz.ratio(str(csv_circuit_lng).lower(), str(db_circuit_lng).lower())
            
            
            # Quarantine the potentially incorrect if the names or coordinates of csv record 
            # are similar to db record but location in csv file is different
            # The records are termed as errored if the location is different but still either coordinates or name or circuit reference is same
            # This is because one location can have multiple circuits and multiple names or coordinates or circuit references
            # But same coordinates or circuit reference should not be present in diffrent locations
            if row_csv[7] == 'left_only':
                if ((lat_score>=threshold and lng_score>=threshold and circuit_ref_score>=threshold) or name_score>=95 or circuit_ref_score>=threshold):
                    # add a logger saying potentially incorrect record found, quarantining the same
                    csv_circuit_quarantine = {'circuitId': row_csv[0],'circuitRef': row_csv[1],'name': row_csv[2],'location': row_csv[3],'lat': row_csv[5],'lng': row_csv[6]}
                    quarantine_lst.append(csv_circuit_quarantine)
                    # print("==================")
                    # print(row_csv)
                    # print(row_db)
                    match_found = True
                    break
            
            # Records matched if the names or coordinates of csv record are similar to db record
            # and location of both is same. So no action on them
            elif row_csv[7] == 'both':
                if ((lat_score>=threshold and lng_score>=threshold and circuit_ref_score>=threshold) or name_score>=threshold):
                    match_found = True
                    break
    
        if not match_found:
            csv_circuit = {'circuit_reference': row_csv[1],'name': row_csv[2],'location': row_csv[3],'lat': row_csv[5],'lng': row_csv[6]}
            insert_list.append(csv_circuit)
    # quarantine_lst
    # insert_list
    result_report(insert_list, quarantine_lst)
except Exception as e:
    logger.error("Error in processing the data: %s", e)
# Out:
# 2023-10-02 08:00:42.875 INFO 1410904026 - <module>: Analysing and filtering datasets
# 2023-10-02 08:00:42.903 INFO 3631209349 - result_report: Report - Total # of new circuits inserted is: 53, Total # of circuits quarantined for analysis is: 4

# %% [markdown]
# Converting the list of dictionaries into dataframes for efficient inserting into database and for better analysis of quarantined records

# %%
df_insert = pd.DataFrame(insert_list)
df_quarantine = pd.DataFrame(quarantine_lst)

# %% [markdown]
# Logic to fetch the last circuits id in the postgres table and then insert the unmatched records with incremented ids

# %%
conn_string = 'postgresql://admin:admin@pgdb/postgres'
  
db = create_engine(conn_string)
conn = db.connect()
conn = psycopg2.connect(conn_string)
conn.autocommit = True
cursor = conn.cursor()
  
# sql1 = '''select max(circuit_id) from race_data.circuits;'''
# cursor.execute(sql1)
# for i in cursor.fetchall():
#     max_id=i[0]
# df_insert.index += max_id
# df_insert_full=df_insert.reset_index().rename(columns={'index':'circuit_id'})
table_name = 'circuits'
df_insert.to_sql(table_name, engine, if_exists='append', index=False, schema='race_data')
conn.close()

# %%
## Check for how the dataframe lookslike now
df_db = pd.read_sql("SELECT * FROM race_data.circuits", engine)
df_db
# Out:
#     circuit_id circuit_reference  \
# 0            1          Montreal
# 1            2         Melbourne
# 2            3         Spielberg
# 3            4       Silverstone
# 4            5         Barcelona
# 5            6               Spa
# 6            7             Monza
# 7            8             Sochi
# 8            9       Nurburgring
# 9           10          Portimao
# 10          11           Mugello
# 11          12            Sakhir
# 12          13             Imola
# 13          14            Monaco
# 14          15              Baku
# 15          16       Paul Ricard
# 16          17       Hungaroring
# 17          18         Zandvoort
# 18          19             Hanoi
# 19          20            Austin
# 20          21            Mexico
# 21          22            Jeddah
# 22          23         Abu Dhabi
# 23          24         Las Vegas
# 24          25             Miami
# 25          26          adelaide
# 26          27            losail
# 27          28        anderstorp
# 28          29          montjuic
# 29          30         pedralbes
# 30          31              avus
# 31          32        bremgarten
# 32          33          nivelles
# 33          34            galvez
# 34          35         riverside
# 35          36        long beach
# 36          37          ain diab
# 37          38         donington
# 38          39           charade
# 39          40            dallas
# 40          41           detroit
# 41          42             dijon
# 42          43            george
# 43          44           estoril
# 44          45           sebring
# 45          46            zolder
# 46          47    hockenheimring
# 47          48      indianapolis
# 48          49          istanbul
# 49          50             jerez
# 50          51      brands hatch
# 51          52            sepang
# 52          53            lemans
# 53          54          monsanto
# 54          55           aintree
# 55          56            jarama
# 56          57       magny cours
# 57          58        marina bay
# 58          59       albert park
# 59          60           kyalami
# 60          61      watkins glen
# 61          62           okayama
# 62          63           mosport
# 63          64          boavista
# 64          65              fuji
# 65          66           pescara
# 66          67           phoenix
# 67          68         tremblant
# 68          69             reims
# 69          70       jacarepagua
# 70          71           essarts
# 71          72        interlagos
# 72          73          shanghai
# 73          74           zeltweg
# 74          75            suzuka
# 75          76             buddh
# 76          77          valencia
# 77          78           yeongam
#
#                                             name               location  \
# 0                      Circuit Gilles-Villeneuve               Montreal
# 1                   Melbourne Grand Prix Circuit              Melbourne
# 2                                  Red Bull Ring              Spielberg
# 3                            Silverstone Circuit            Silverstone
# 4                 Circuit de Barcelona-Catalunya               Montmelo
# 5                   Circuit de Spa-Francorchamps      Spa Francorchamps
# 6                      Autodromo Nazionale Monza                  Monza
# 7                                 Sochi Autodrom                  Sochi
# 8                                    Nürburgring                Nürburg
# 9             Autódromo Internacional do Algarve               Portimão
# 10          Autodromo Internazionale del Mugello  Scarperia e San Piero
# 11                 Bahrain International Circuit                 Sakhir
# 12  Autodromo Internazionale Enzo e Dino Ferrari                  Imola
# 13                             Circuit de Monaco            Monte Carlo
# 14                             Baku City Circuit                   Baku
# 15                           Circuit Paul Ricard           Le Castellet
# 16                                   Hungaroring               Mogyorod
# 17                             Circuit Zandvoort              Zandvoort
# 18                          Hanoi Street Circuit                  Hanoi
# 19                       Circuit of The Americas                 Austin
# 20                  Autódromo Hermanos Rodríguez            Mexico City
# 21                         Jeddah Street Circuit                 Jeddah
# 22                            Yas Marina Circuit              Abu Dhabi
# 23                      Las Vegas Street Circuit              Las Vegas
# 24                 Miami International Autodrome                  Miami
# 25                       Adelaide Street Circuit               Adelaide
# 26                  Losail International Circuit              Al Daayen
# 27                          Scandinavian Raceway             Anderstorp
# 28                                      Montjuic              Barcelona
# 29                          Circuit de Pedralbes              Barcelona
# 30                                          AVUS                 Berlin
# 31                            Circuit Bremgarten                   Bern
# 32                              Nivelles Baulers               Brussels
# 33                 Autodromo Juan y Oscar Galvez           Buenos Aires
# 34               Riverside International Raceway             California
# 35                                    Long Beach             California
# 36                                      Ain Diab             Casablanca
# 37                                Donington Park       Castle Donington
# 38                               Charade Circuit       Clermont Ferrand
# 39                                     Fair Park                 Dallas
# 40                        Detroit Street Circuit                Detroit
# 41                                 Dijon Prenois                  Dijon
# 42                         Prince George Circuit  Eastern Cape Province
# 43                          Autodromo do Estoril                Estoril
# 44                 Sebring International Raceway                Florida
# 45                                        Zolder         Heusden Zolder
# 46                                Hockenheimring             Hockenheim
# 47                   Indianapolis Motor Speedway           Indianapolis
# 48                                 Istanbul Park               Istanbul
# 49                             Circuito de Jerez   Jerez de la Frontera
# 50                                  Brands Hatch                   Kent
# 51                  Sepang International Circuit           Kuala Lumpur
# 52                                       Le Mans                Le Mans
# 53                         Monsanto Park Circuit                 Lisbon
# 54                                       Aintree              Liverpool
# 55                                        Jarama                 Madrid
# 56                 Circuit de Nevers Magny Cours            Magny Cours
# 57                     Marina Bay Street Circuit             Marina Bay
# 58                Albert Park Grand Prix Circuit              Melbourne
# 59                                       Kyalami                Midrand
# 60                                  Watkins Glen         New York State
# 61                 Okayama International Circuit                Okayama
# 62                 Mosport International Raceway                Ontario
# 63                          Circuito da Boavista                 Oporto
# 64                                 Fuji Speedway                  Oyama
# 65                               Pescara Circuit                Pescara
# 66                        Phoenix street circuit                Phoenix
# 67                        Circuit Mont Tremblant                 Quebec
# 68                                   Reims Gueux                  Reims
# 69         Autodromo Internacional Nelson Piquet         Rio de Janeiro
# 70                             Rouen Les Essarts                  Rouen
# 71                    Autodromo Jose Carlos Pace              Sao Paulo
# 72                Shanghai International Circuit               Shanghai
# 73                                       Zeltweg                 Styria
# 74                                Suzuka Circuit                 Suzuka
# 75                   Buddh International Circuit          Uttar Pradesh
# 76                       Valencia Street Circuit               Valencia
# 77                  Korean International Circuit         Yeongam County
#
#          lat         lng
# 0   45.50600  -73.525000
# 1  -37.84970  144.968000
# 2   47.22300   14.761000
# 3   52.07200   -1.017000
# 4   41.56900    2.261000
# 5   50.43600    5.971000
# 6   45.62100    9.290000
# 7   43.40700   39.960000
# 8   50.33400    6.943000
# 9   37.23200   -8.628000
# 10  43.99800   11.372000
# 11  26.03100   50.512000
# 12  44.34300   11.716000
# 13  43.73500    7.421000
# 14  40.37200   49.853000
# 15  43.25100    5.793000
# 16  47.58100   19.250000
# 17  52.38900    4.541000
# 18  21.02100  105.843000
# 19  30.13300  -97.641000
# 20  19.40600  -99.090000
# 21  21.52700   39.187000
# 22  24.47000   54.603000
# 23  36.16900 -115.136000
# 24  25.77800  -80.202000
# 25 -34.92720  138.617000
# 26  25.49000   51.454200
# 27  57.26530   13.604200
# 28  41.36640    2.151670
# 29  41.39030    2.116670
# 30  52.48060   13.251400
# 31  46.95890    7.401940
# 32  50.62110    4.326940
# 33 -34.69430  -58.459300
# 34  33.93700 -117.273000
# 35  33.76510 -118.189000
# 36  33.57860   -7.687500
# 37  52.83060   -1.375280
# 38  45.74720    3.038890
# 39  32.77740  -96.758700
# 40  42.32980  -83.040100
# 41  47.36250    4.899130
# 42 -33.04860   27.873600
# 43  38.75060   -9.394170
# 44  27.45470  -81.348300
# 45  50.98940    5.256940
# 46  49.32780    8.565830
# 47  39.79500  -86.234700
# 48  40.95170   29.405000
# 49  36.70830   -6.034170
# 50  51.35690    0.263056
# 51   2.76083  101.738000
# 52  47.95000    0.224231
# 53  38.71970   -9.203060
# 54  53.47690   -2.940560
# 55  40.61710   -3.585580
# 56  46.86420    3.163610
# 57   1.29140  103.864000
# 58 -37.84970  144.968000
# 59 -25.98940   28.076700
# 60  42.33690  -76.927200
# 61  34.91500  134.221000
# 62  44.04810  -78.675600
# 63  41.17050   -8.673250
# 64  35.37170  138.927000
# 65  42.47500   14.150800
# 66  33.44790 -112.075000
# 67  46.18770  -74.609900
# 68  49.25420    3.930830
# 69 -22.97560  -43.395000
# 70  49.33060    1.004580
# 71 -23.70360  -46.699700
# 72  31.33890  121.220000
# 73  47.20390   14.747800
# 74  34.84310  136.541000
# 75  28.34870   77.533100
# 76  39.45890   -0.331667
# 77  34.73330  126.417000

# %%
## Check for false positives

# %%
# Define the last_index variable to track the last index used in the DataFrame
last_index = 0

# Define an empty DataFrame
duplicates = pd.DataFrame(columns=['index1', 'index2', 'circuit_reference1', 'circuit_reference2', 'name1', 'name2', 'location1', 'location2', 'score'])

for i in range(len(df_db)):
    for j in range(i+1, len(df_db)):
        circuit_reference1 = df_db.iloc[i]['circuit_reference']
        circuit_reference2 = df_db.iloc[j]['circuit_reference']
        name1 = df_db.iloc[i]['name']
        name2 = df_db.iloc[j]['name']
        location1 = df_db.iloc[i]['location']
        location2 = df_db.iloc[j]['location']
        
        # Calculate the fuzzy match score for circuit_reference, name and location fields
        circuit_reference_score = fuzz.ratio(circuit_reference1.lower(), circuit_reference2.lower())
        name_score = fuzz.ratio(name1.lower(), name2.lower())
        location_score = fuzz.ratio(location1.lower(), location2.lower())
        
        # If the score is above a threshold (e.g. 80) for circuit_reference, name or location, consider them as potential duplicates
        if ((circuit_reference_score > 80 or name_score > 80) and location_score > 80):
            duplicates.loc[last_index] = {
                'index1': df_db.iloc[i]['circuit_id'],
                'index2': df_db.iloc[j]['circuit_id'],
                'circuit_reference1': circuit_reference1,
                'circuit_reference2': circuit_reference2,
                'name1': name1,
                'name2': name2,
                'location1': location1,
                'location2': location2,
                'score': max(circuit_reference_score, name_score, location_score)
            }
            last_index += 1

# Show the potential duplicates
duplicates
# Out:
# Empty DataFrame
# Columns: [index1, index2, circuit_reference1, circuit_reference2, name1, name2, location1, location2, score]
# Index: []

# %% [markdown]
#                                                          # End of the notebook
